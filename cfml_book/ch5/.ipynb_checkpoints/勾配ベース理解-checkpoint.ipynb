# %% [markdown]
# # 勾配ベース理解

# %%
import warnings
warnings.filterwarnings('ignore')

import torch
import numpy as np
import pandas as pd
from pandas import DataFrame
from tqdm import tqdm
from sklearn.utils import check_random_state
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib
plt.style.use('ggplot')

from dataset import generate_synthetic_data
from policylearners import RegBasedPolicyLearner, GradientBasedPolicyLearner, POTEC
from utils import softmax

# %%
## シミュレーション設定
num_runs = 100 # シミュレーションの繰り返し回数
dim_x = 5 # 特徴量xの次元
num_actions = 2 # 行動数, |A|
num_clusters = 2 # 行動クラスタ数, |C|
lambda_ = 0.5 # クラスタ効果と残差効果の配合率
max_iter = 31 # エポック数
test_data_size = 50000 # テストデータのサイズ
random_state = 12345
torch.manual_seed(random_state)
random_ = check_random_state(random_state)
num_data_list = [100, 200, 500, 1000, 2000] # トレーニングデータのサイズ

# num_data = num_data_list[4] # 2,000
num_data = num_data_list[0] # 100

## 期待報酬関数を定義するためのパラメータを抽出
phi_a = random_.choice(num_clusters, size=num_actions)
theta_g = random_.normal(size=(dim_x, num_clusters))
M_g = random_.normal(size=(dim_x, num_clusters))
b_g = random_.normal(size=(1, num_clusters))
theta_h = random_.normal(size=(dim_x, num_actions))
M_h = random_.normal(size=(dim_x, num_actions))
b_h = random_.normal(size=(1, num_actions))

## 学習された方策の真の性能を近似するためのテストデータを生成
test_data = generate_synthetic_data(
    num_data=test_data_size, lambda_=lambda_,
    theta_g=theta_g, M_g=M_g, b_g=b_g, theta_h=theta_h, M_h=M_h, b_h=b_h, phi_a=phi_a,
    dim_context=dim_x, num_actions=num_actions, num_clusters=num_clusters, random_state = random_state
)
pi_0_value = (test_data["q_x_a"] * test_data["pi_0"]).sum(1).mean()

## データ収集方策が形成する分布に従いログデータを生成
offline_logged_data = generate_synthetic_data(
    num_data=num_data, lambda_=lambda_,
    theta_g=theta_g, M_g=M_g, b_g=b_g, theta_h=theta_h, M_h=M_h, b_h=b_h, phi_a=phi_a,
    dim_context=dim_x, num_actions=num_actions, num_clusters=num_clusters,
    # random_state = _
    random_state = random_state
)

# %%
# 辞書型で直観的にわかりづらいのでdfに変換
# log_data->log_data_df
data = offline_logged_data.copy()
df = pd.DataFrame(data['x'], columns=['x_'+str(i) for i in range(data['x'].shape[1])])
df['a'] = data['a']
df['r'] = data['r']
ex_reward_df = pd.DataFrame(data['q_x_a'], columns=['q_x_'+str(i) for i in range(data['num_actions'])])
df = pd.concat([df, ex_reward_df], axis=1)
pi_b_df = pd.DataFrame(data['pi_0'].reshape(data['num_data'], data['num_actions']), columns=['pi_0_'+str(i) for i in range(data['num_actions'])])
df = pd.concat([df, pi_b_df], axis=1)
df['pscore'] = data['pscore']
df
# Out:
#          x_0       x_1       x_2       x_3       x_4  a  r     q_x_0  \
# 0  -0.204708  0.478943 -0.519439 -0.555730  1.965781  1  0  0.175144
# 1   1.393406  0.092908  0.281746  0.769023  1.246435  0  0  0.357402
# 2   1.007189 -1.296221  0.274992  0.228913  1.352917  0  0  0.086599
# 3   0.886429 -2.001637 -0.371843  1.669025 -0.438570  0  0  0.000486
# 4  -0.539741  0.476985  3.248944 -1.021228 -0.577087  1  1  1.000000
# ..       ...       ...       ...       ...       ... .. ..       ...
# 95  0.398092 -0.916935 -0.082650 -1.939691  1.407994  1  1  0.000950
# 96  1.512406  0.526493 -0.266931  0.862284  0.083803  0  1  0.728565
# 97 -1.872339 -0.962791  0.080067  0.128726 -0.479120  1  1  0.728029
# 98 -0.640281  0.745974 -0.622547  0.936289  0.750018  1  1  0.920900
# 99 -0.056715  2.300675  0.569497  1.489410  1.264250  0  1  0.999998
#
#        q_x_1    pi_0_0    pi_0_1    pscore
# 0   0.042578  0.431547  0.568453  0.568453
# 1   0.026896  0.545722  0.454278  0.545722
# 2   0.165448  0.561380  0.438620  0.561380
# 3   0.777752  0.381532  0.618468  0.381532
# 4   1.000000  0.440605  0.559395  0.559395
# ..       ...       ...       ...       ...
# 95  0.456561  0.442579  0.557421  0.557421
# 96  0.313117  0.620969  0.379031  0.620969
# 97  0.998228  0.442754  0.557246  0.557246
# 98  0.913424  0.549833  0.450167  0.450167
# 99  0.999960  0.627659  0.372341  0.627659
#
# [100 rows x 12 columns]

# %%
# df.to_csv('offline_logged_data.csv', index=False)

# %%
### 勾配ベースのアプローチ (IPS推定量で方策勾配を推定)
ips = GradientBasedPolicyLearner(dim_x=dim_x, num_actions=num_actions, max_iter=max_iter, batch_size=10)
_list = ips.fit(offline_logged_data, test_data)
_list
# Out:
# [tensor(0.2291, grad_fn=<NegBackward0>),
#  tensor(0.5751, grad_fn=<NegBackward0>),
#  tensor(0.4930, grad_fn=<NegBackward0>),
#  tensor(0.3968, grad_fn=<NegBackward0>),
#  tensor(0.4378, grad_fn=<NegBackward0>),
#  tensor(0.5375, grad_fn=<NegBackward0>),
#  tensor(0.3900, grad_fn=<NegBackward0>),
#  tensor(0.4003, grad_fn=<NegBackward0>),
#  tensor(0.1012, grad_fn=<NegBackward0>),
#  tensor(0.3841, grad_fn=<NegBackward0>),
#  tensor(0.1568, grad_fn=<NegBackward0>),
#  tensor(0.4551, grad_fn=<NegBackward0>),
#  tensor(0.3906, grad_fn=<NegBackward0>),
#  tensor(0.2970, grad_fn=<NegBackward0>),
#  tensor(0.3825, grad_fn=<NegBackward0>),
#  tensor(0.4308, grad_fn=<NegBackward0>),
#  tensor(0.3459, grad_fn=<NegBackward0>),
#  tensor(0.3285, grad_fn=<NegBackward0>),
#  tensor(0.0934, grad_fn=<NegBackward0>),
#  tensor(0.3073, grad_fn=<NegBackward0>),
#  tensor(0.1116, grad_fn=<NegBackward0>),
#  tensor(0.3572, grad_fn=<NegBackward0>),
#  tensor(0.3088, grad_fn=<NegBackward0>),
#  tensor(0.2225, grad_fn=<NegBackward0>),
#  tensor(0.3478, grad_fn=<NegBackward0>),
#  tensor(0.3422, grad_fn=<NegBackward0>),
#  tensor(0.3077, grad_fn=<NegBackward0>),
#  tensor(0.2671, grad_fn=<NegBackward0>),
#  tensor(0.0844, grad_fn=<NegBackward0>),
#  tensor(0.2552, grad_fn=<NegBackward0>),
#  tensor(0.0849, grad_fn=<NegBackward0>),
#  tensor(0.2889, grad_fn=<NegBackward0>),
#  tensor(0.2493, grad_fn=<NegBackward0>),
#  tensor(0.1741, grad_fn=<NegBackward0>),
#  tensor(0.3280, grad_fn=<NegBackward0>),
#  tensor(0.2766, grad_fn=<NegBackward0>),
#  tensor(0.2787, grad_fn=<NegBackward0>),
#  tensor(0.2213, grad_fn=<NegBackward0>),
#  tensor(0.0770, grad_fn=<NegBackward0>),
#  tensor(0.2218, grad_fn=<NegBackward0>),
#  tensor(0.0692, grad_fn=<NegBackward0>),
#  tensor(0.2433, grad_fn=<NegBackward0>),
#  tensor(0.2074, grad_fn=<NegBackward0>),
#  tensor(0.1435, grad_fn=<NegBackward0>),
#  tensor(0.3169, grad_fn=<NegBackward0>),
#  tensor(0.2295, grad_fn=<NegBackward0>),
#  tensor(0.2582, grad_fn=<NegBackward0>),
#  tensor(0.1883, grad_fn=<NegBackward0>),
#  tensor(0.0713, grad_fn=<NegBackward0>),
#  tensor(0.2002, grad_fn=<NegBackward0>),
#  tensor(0.0596, grad_fn=<NegBackward0>),
#  tensor(0.2125, grad_fn=<NegBackward0>),
#  tensor(0.1776, grad_fn=<NegBackward0>),
#  tensor(0.1234, grad_fn=<NegBackward0>),
#  tensor(0.3105, grad_fn=<NegBackward0>),
#  tensor(0.1953, grad_fn=<NegBackward0>),
#  tensor(0.2440, grad_fn=<NegBackward0>),
#  tensor(0.1643, grad_fn=<NegBackward0>),
#  tensor(0.0668, grad_fn=<NegBackward0>),
#  tensor(0.1857, grad_fn=<NegBackward0>),
#  tensor(0.0535, grad_fn=<NegBackward0>),
#  tensor(0.1913, grad_fn=<NegBackward0>),
#  tensor(0.1556, grad_fn=<NegBackward0>),
#  tensor(0.1092, grad_fn=<NegBackward0>),
#  tensor(0.3067, grad_fn=<NegBackward0>),
#  tensor(0.1700, grad_fn=<NegBackward0>),
#  tensor(0.2344, grad_fn=<NegBackward0>),
#  tensor(0.1466, grad_fn=<NegBackward0>),
#  tensor(0.0631, grad_fn=<NegBackward0>),
#  tensor(0.1756, grad_fn=<NegBackward0>),
#  tensor(0.0496, grad_fn=<NegBackward0>),
#  tensor(0.1762, grad_fn=<NegBackward0>),
#  tensor(0.1390, grad_fn=<NegBackward0>),
#  tensor(0.0982, grad_fn=<NegBackward0>),
#  tensor(0.3039, grad_fn=<NegBackward0>),
#  tensor(0.1506, grad_fn=<NegBackward0>),
#  tensor(0.2280, grad_fn=<NegBackward0>),
#  tensor(0.1331, grad_fn=<NegBackward0>),
#  tensor(0.0598, grad_fn=<NegBackward0>),
#  tensor(0.1683, grad_fn=<NegBackward0>),
#  tensor(0.0471, grad_fn=<NegBackward0>),
#  tensor(0.1653, grad_fn=<NegBackward0>),
#  tensor(0.1261, grad_fn=<NegBackward0>),
#  tensor(0.0890, grad_fn=<NegBackward0>),
#  tensor(0.3011, grad_fn=<NegBackward0>),
#  tensor(0.1354, grad_fn=<NegBackward0>),
#  tensor(0.2239, grad_fn=<NegBackward0>),
#  tensor(0.1227, grad_fn=<NegBackward0>),
#  tensor(0.0568, grad_fn=<NegBackward0>),
#  tensor(0.1627, grad_fn=<NegBackward0>),
#  tensor(0.0456, grad_fn=<NegBackward0>),
#  tensor(0.1574, grad_fn=<NegBackward0>),
#  tensor(0.1157, grad_fn=<NegBackward0>),
#  tensor(0.0808, grad_fn=<NegBackward0>),
#  tensor(0.2978, grad_fn=<NegBackward0>),
#  tensor(0.1232, grad_fn=<NegBackward0>),
#  tensor(0.2211, grad_fn=<NegBackward0>),
#  tensor(0.1145, grad_fn=<NegBackward0>),
#  tensor(0.0537, grad_fn=<NegBackward0>),
#  tensor(0.1583, grad_fn=<NegBackward0>),
#  tensor(0.0447, grad_fn=<NegBackward0>),
#  tensor(0.1514, grad_fn=<NegBackward0>),
#  tensor(0.1072, grad_fn=<NegBackward0>),
#  tensor(0.0732, grad_fn=<NegBackward0>),
#  tensor(0.2936, grad_fn=<NegBackward0>),
#  tensor(0.1132, grad_fn=<NegBackward0>),
#  tensor(0.2191, grad_fn=<NegBackward0>),
#  tensor(0.1078, grad_fn=<NegBackward0>),
#  tensor(0.0507, grad_fn=<NegBackward0>),
#  tensor(0.1545, grad_fn=<NegBackward0>),
#  tensor(0.0443, grad_fn=<NegBackward0>),
#  tensor(0.1468, grad_fn=<NegBackward0>),
#  tensor(0.1000, grad_fn=<NegBackward0>),
#  tensor(0.0662, grad_fn=<NegBackward0>),
#  tensor(0.2887, grad_fn=<NegBackward0>),
#  tensor(0.1049, grad_fn=<NegBackward0>),
#  tensor(0.2176, grad_fn=<NegBackward0>),
#  tensor(0.1022, grad_fn=<NegBackward0>),
#  tensor(0.0476, grad_fn=<NegBackward0>),
#  tensor(0.1510, grad_fn=<NegBackward0>),
#  tensor(0.0442, grad_fn=<NegBackward0>),
#  tensor(0.1432, grad_fn=<NegBackward0>),
#  tensor(0.0939, grad_fn=<NegBackward0>),
#  tensor(0.0598, grad_fn=<NegBackward0>),
#  tensor(0.2833, grad_fn=<NegBackward0>),
#  tensor(0.0978, grad_fn=<NegBackward0>),
#  tensor(0.2161, grad_fn=<NegBackward0>),
#  tensor(0.0976, grad_fn=<NegBackward0>),
#  tensor(0.0446, grad_fn=<NegBackward0>),
#  tensor(0.1479, grad_fn=<NegBackward0>),
#  tensor(0.0443, grad_fn=<NegBackward0>),
#  tensor(0.1403, grad_fn=<NegBackward0>),
#  tensor(0.0886, grad_fn=<NegBackward0>),
#  tensor(0.0541, grad_fn=<NegBackward0>),
#  tensor(0.2777, grad_fn=<NegBackward0>),
#  tensor(0.0917, grad_fn=<NegBackward0>),
#  tensor(0.2147, grad_fn=<NegBackward0>),
#  tensor(0.0936, grad_fn=<NegBackward0>),
#  tensor(0.0417, grad_fn=<NegBackward0>),
#  tensor(0.1449, grad_fn=<NegBackward0>),
#  tensor(0.0445, grad_fn=<NegBackward0>),
#  tensor(0.1379, grad_fn=<NegBackward0>),
#  tensor(0.0839, grad_fn=<NegBackward0>),
#  tensor(0.0489, grad_fn=<NegBackward0>),
#  tensor(0.2720, grad_fn=<NegBackward0>),
#  tensor(0.0864, grad_fn=<NegBackward0>),
#  tensor(0.2131, grad_fn=<NegBackward0>),
#  tensor(0.0901, grad_fn=<NegBackward0>),
#  tensor(0.0390, grad_fn=<NegBackward0>),
#  tensor(0.1421, grad_fn=<NegBackward0>),
#  tensor(0.0448, grad_fn=<NegBackward0>),
#  tensor(0.1358, grad_fn=<NegBackward0>),
#  tensor(0.0798, grad_fn=<NegBackward0>),
#  tensor(0.0444, grad_fn=<NegBackward0>),
#  tensor(0.2666, grad_fn=<NegBackward0>),
#  tensor(0.0817, grad_fn=<NegBackward0>),
#  tensor(0.2114, grad_fn=<NegBackward0>),
#  tensor(0.0871, grad_fn=<NegBackward0>),
#  tensor(0.0364, grad_fn=<NegBackward0>),
#  tensor(0.1395, grad_fn=<NegBackward0>),
#  tensor(0.0451, grad_fn=<NegBackward0>),
#  tensor(0.1340, grad_fn=<NegBackward0>),
#  tensor(0.0761, grad_fn=<NegBackward0>),
#  tensor(0.0405, grad_fn=<NegBackward0>),
#  tensor(0.2614, grad_fn=<NegBackward0>),
#  tensor(0.0775, grad_fn=<NegBackward0>),
#  tensor(0.2097, grad_fn=<NegBackward0>),
#  tensor(0.0843, grad_fn=<NegBackward0>),
#  tensor(0.0340, grad_fn=<NegBackward0>),
#  tensor(0.1370, grad_fn=<NegBackward0>),
#  tensor(0.0454, grad_fn=<NegBackward0>),
#  tensor(0.1325, grad_fn=<NegBackward0>),
#  tensor(0.0728, grad_fn=<NegBackward0>),
#  tensor(0.0371, grad_fn=<NegBackward0>),
#  tensor(0.2567, grad_fn=<NegBackward0>),
#  tensor(0.0738, grad_fn=<NegBackward0>),
#  tensor(0.2078, grad_fn=<NegBackward0>),
#  tensor(0.0818, grad_fn=<NegBackward0>),
#  tensor(0.0318, grad_fn=<NegBackward0>),
#  tensor(0.1346, grad_fn=<NegBackward0>),
#  tensor(0.0457, grad_fn=<NegBackward0>),
#  tensor(0.1311, grad_fn=<NegBackward0>),
#  tensor(0.0698, grad_fn=<NegBackward0>),
#  tensor(0.0341, grad_fn=<NegBackward0>),
#  tensor(0.2522, grad_fn=<NegBackward0>),
#  tensor(0.0705, grad_fn=<NegBackward0>),
#  tensor(0.2060, grad_fn=<NegBackward0>),
#  tensor(0.0796, grad_fn=<NegBackward0>),
#  tensor(0.0299, grad_fn=<NegBackward0>),
#  tensor(0.1323, grad_fn=<NegBackward0>),
#  tensor(0.0460, grad_fn=<NegBackward0>),
#  tensor(0.1298, grad_fn=<NegBackward0>),
#  tensor(0.0671, grad_fn=<NegBackward0>),
#  tensor(0.0315, grad_fn=<NegBackward0>),
#  tensor(0.2482, grad_fn=<NegBackward0>),
#  tensor(0.0674, grad_fn=<NegBackward0>),
#  tensor(0.2041, grad_fn=<NegBackward0>),
#  tensor(0.0775, grad_fn=<NegBackward0>),
#  tensor(0.0281, grad_fn=<NegBackward0>),
#  tensor(0.1302, grad_fn=<NegBackward0>),
#  tensor(0.0462, grad_fn=<NegBackward0>),
#  tensor(0.1286, grad_fn=<NegBackward0>),
#  tensor(0.0646, grad_fn=<NegBackward0>),
#  tensor(0.0292, grad_fn=<NegBackward0>),
#  tensor(0.2445, grad_fn=<NegBackward0>),
#  tensor(0.0647, grad_fn=<NegBackward0>),
#  tensor(0.2023, grad_fn=<NegBackward0>),
#  tensor(0.0756, grad_fn=<NegBackward0>),
#  tensor(0.0265, grad_fn=<NegBackward0>),
#  tensor(0.1281, grad_fn=<NegBackward0>),
#  tensor(0.0464, grad_fn=<NegBackward0>),
#  tensor(0.1275, grad_fn=<NegBackward0>),
#  tensor(0.0623, grad_fn=<NegBackward0>),
#  tensor(0.0272, grad_fn=<NegBackward0>),
#  tensor(0.2411, grad_fn=<NegBackward0>),
#  tensor(0.0622, grad_fn=<NegBackward0>),
#  tensor(0.2005, grad_fn=<NegBackward0>),
#  tensor(0.0738, grad_fn=<NegBackward0>),
#  tensor(0.0250, grad_fn=<NegBackward0>),
#  tensor(0.1262, grad_fn=<NegBackward0>),
#  tensor(0.0465, grad_fn=<NegBackward0>),
#  tensor(0.1265, grad_fn=<NegBackward0>),
#  tensor(0.0602, grad_fn=<NegBackward0>),
#  tensor(0.0254, grad_fn=<NegBackward0>),
#  tensor(0.2380, grad_fn=<NegBackward0>),
#  tensor(0.0599, grad_fn=<NegBackward0>),
#  tensor(0.1988, grad_fn=<NegBackward0>),
#  tensor(0.0722, grad_fn=<NegBackward0>),
#  tensor(0.0237, grad_fn=<NegBackward0>),
#  tensor(0.1244, grad_fn=<NegBackward0>),
#  tensor(0.0466, grad_fn=<NegBackward0>),
#  tensor(0.1256, grad_fn=<NegBackward0>),
#  tensor(0.0583, grad_fn=<NegBackward0>),
#  tensor(0.0238, grad_fn=<NegBackward0>),
#  tensor(0.2352, grad_fn=<NegBackward0>),
#  tensor(0.0578, grad_fn=<NegBackward0>),
#  tensor(0.1971, grad_fn=<NegBackward0>),
#  tensor(0.0707, grad_fn=<NegBackward0>),
#  tensor(0.0225, grad_fn=<NegBackward0>),
#  tensor(0.1227, grad_fn=<NegBackward0>),
#  tensor(0.0467, grad_fn=<NegBackward0>),
#  tensor(0.1247, grad_fn=<NegBackward0>),
#  tensor(0.0565, grad_fn=<NegBackward0>),
#  tensor(0.0224, grad_fn=<NegBackward0>),
#  tensor(0.2326, grad_fn=<NegBackward0>),
#  tensor(0.0559, grad_fn=<NegBackward0>),
#  tensor(0.1955, grad_fn=<NegBackward0>),
#  tensor(0.0692, grad_fn=<NegBackward0>),
#  tensor(0.0215, grad_fn=<NegBackward0>),
#  tensor(0.1211, grad_fn=<NegBackward0>),
#  tensor(0.0468, grad_fn=<NegBackward0>),
#  tensor(0.1239, grad_fn=<NegBackward0>),
#  tensor(0.0548, grad_fn=<NegBackward0>),
#  tensor(0.0211, grad_fn=<NegBackward0>),
#  tensor(0.2302, grad_fn=<NegBackward0>),
#  tensor(0.0542, grad_fn=<NegBackward0>),
#  tensor(0.1939, grad_fn=<NegBackward0>),
#  tensor(0.0679, grad_fn=<NegBackward0>),
#  tensor(0.0205, grad_fn=<NegBackward0>),
#  tensor(0.1195, grad_fn=<NegBackward0>),
#  tensor(0.0469, grad_fn=<NegBackward0>),
#  tensor(0.1231, grad_fn=<NegBackward0>),
#  tensor(0.0533, grad_fn=<NegBackward0>),
#  tensor(0.0200, grad_fn=<NegBackward0>),
#  tensor(0.2280, grad_fn=<NegBackward0>),
#  tensor(0.0525, grad_fn=<NegBackward0>),
#  tensor(0.1925, grad_fn=<NegBackward0>),
#  tensor(0.0666, grad_fn=<NegBackward0>),
#  tensor(0.0196, grad_fn=<NegBackward0>),
#  tensor(0.1181, grad_fn=<NegBackward0>),
#  tensor(0.0469, grad_fn=<NegBackward0>),
#  tensor(0.1224, grad_fn=<NegBackward0>),
#  tensor(0.0518, grad_fn=<NegBackward0>),
#  tensor(0.0190, grad_fn=<NegBackward0>),
#  tensor(0.2260, grad_fn=<NegBackward0>),
#  tensor(0.0510, grad_fn=<NegBackward0>),
#  tensor(0.1911, grad_fn=<NegBackward0>),
#  tensor(0.0654, grad_fn=<NegBackward0>),
#  tensor(0.0188, grad_fn=<NegBackward0>),
#  tensor(0.1167, grad_fn=<NegBackward0>),
#  tensor(0.0469, grad_fn=<NegBackward0>),
#  tensor(0.1217, grad_fn=<NegBackward0>),
#  tensor(0.0505, grad_fn=<NegBackward0>),
#  tensor(0.0181, grad_fn=<NegBackward0>),
#  tensor(0.2241, grad_fn=<NegBackward0>),
#  tensor(0.0496, grad_fn=<NegBackward0>),
#  tensor(0.1898, grad_fn=<NegBackward0>),
#  tensor(0.0643, grad_fn=<NegBackward0>),
#  tensor(0.0181, grad_fn=<NegBackward0>),
#  tensor(0.1154, grad_fn=<NegBackward0>),
#  tensor(0.0469, grad_fn=<NegBackward0>),
#  tensor(0.1210, grad_fn=<NegBackward0>),
#  tensor(0.0492, grad_fn=<NegBackward0>),
#  tensor(0.0172, grad_fn=<NegBackward0>),
#  tensor(0.2224, grad_fn=<NegBackward0>),
#  tensor(0.0483, grad_fn=<NegBackward0>),
#  tensor(0.1885, grad_fn=<NegBackward0>),
#  tensor(0.0632, grad_fn=<NegBackward0>),
#  tensor(0.0174, grad_fn=<NegBackward0>),
#  tensor(0.1141, grad_fn=<NegBackward0>),
#  tensor(0.0469, grad_fn=<NegBackward0>),
#  tensor(0.1204, grad_fn=<NegBackward0>),
#  tensor(0.0481, grad_fn=<NegBackward0>),
#  tensor(0.0165, grad_fn=<NegBackward0>),
#  tensor(0.2208, grad_fn=<NegBackward0>),
#  tensor(0.0470, grad_fn=<NegBackward0>),
#  tensor(0.1873, grad_fn=<NegBackward0>),
#  tensor(0.0622, grad_fn=<NegBackward0>),
#  tensor(0.0168, grad_fn=<NegBackward0>),
#  tensor(0.1129, grad_fn=<NegBackward0>)]
